# %%
# 0. import packages
	
import time
import numpy as np
import torch
import torch.cuda
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

import matplotlib.pyplot as plt

# %%
#1.1 GPU stuff

print ("cuda: ", torch.cuda.is_available())
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

print ("current device: ", device)
print ("count: ", torch.cuda.device_count())

if torch.cuda.is_available():
    print ("device name: ", torch.cuda.get_device_name(0))
    torch.cuda.set_device(0)
# Out:
# cuda:  True
# current device:  cuda:0
# count:  1
# device name:  NVIDIA GeForce GTX 1660 Ti

# %%
# 1.2 load provided dataset

data = np.load('lab2_dataset.npz')
# training and testing features
train_feats = torch.tensor(data['train_feats'], requires_grad=True)
test_feats = torch.tensor(data['test_feats'], requires_grad=True)
# training and testing labels
train_labels = torch.tensor(data['train_labels'])
test_labels = torch.tensor(data['test_labels'])
# phonemes
phone_labels = data['phone_labels']

print ("train_feats.shape: ", train_feats.shape)
#print ("train_feats: ", train_feats)
print ("--------")

print ("test_feats.shape: ", test_feats.shape)
# print ("test_feats: ", test_feats) 
print ("--------")

print ("train_labels.shape: ", train_labels.shape)
print ("train_labels: ", train_labels) 
print ("--------")

print ("test_labels.shape: ", test_labels.shape)
print ("test_labels: ", test_labels)
print ("--------")

print ("phone_labels.shape: ", phone_labels.shape)
print ("phone_labels: ", phone_labels)
# Out:
# train_feats.shape:  torch.Size([44730, 11, 40])
# --------
# test_feats.shape:  torch.Size([4773, 11, 40])
# --------
# train_labels.shape:  torch.Size([44730])
# train_labels:  tensor([ 0,  0,  0,  ..., 47, 47, 47])
# --------
# test_labels.shape:  torch.Size([4773])
# test_labels:  tensor([ 0,  0,  0,  ..., 40, 40, 40])
# --------
# phone_labels.shape:  (48,)
# phone_labels:  ['sil' 's' 'ao' 'l' 'r' 'iy' 'vcl' 'd' 'eh' 'cl' 'p' 'ix' 'z' 'ih' 'sh'
#  'n' 'v' 'aa' 'y' 'uw' 'w' 'ey' 'dx' 'b' 'ay' 'ng' 'k' 'epi' 'ch' 'dh'
#  'er' 'en' 'g' 'aw' 'hh' 'ae' 'ow' 't' 'ax' 'm' 'zh' 'ah' 'el' 'f' 'jh'
#  'uh' 'oy' 'th']

# %%
#1.3 place tensors on GPU

if torch.cuda.is_available():
    train_feats = train_feats.cuda()
    test_feats = test_feats.cuda()
    train_labels = train_labels.cuda()
    test_labels = test_labels.cuda()

    print ("train_feats.device: ", train_feats.get_device())
    print ("test_feats.device: ", test_feats.get_device())
    print ("train_labels.device: ", train_labels.get_device())
    print ("test_labels.device: ", test_labels.get_device())
# Out:
# train_feats.device:  0
# test_feats.device:  0
# train_labels.device:  0
# test_labels.device:  0

# %%
# 2.  Set up the dataloaders
batch_size = 64

train_dataset = torch.utils.data.TensorDataset(train_feats, train_labels)
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size = batch_size, shuffle = True)

test_dataset = torch.utils.data.TensorDataset(test_feats, test_labels)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size = batch_size, shuffle = False)

# %% [markdown]
# Define the model architecture: /*feed-forward*/ | /*convolutional*/ | /*recurrent*/
# try: tensor.view(), .reshape(), .transpose(), and .permute()
# output: 48-dimensional vector

# %%
# 3.1 Feed-Forward Neural Network

class MyFFNN(nn.Module):
    def __init__(self, model_type, input_dim, output_dim):
        super(MyFFNN, self).__init__()
        # store model type
        self.model_type = model_type
        # store input size
        self.input_size = input_dim
        # batch 1
        self.linear1 = nn.Linear(input_dim, 2048)
        self.relu1 = nn.ReLU()
        # batch 2
        self.linear2 = nn.Linear(2048, 2048)
        self.relu2 = nn.ReLU()
        # batch 3
        self.linear3 = nn.Linear(2048, 2048)
        self.relu3 = nn.ReLU()
        # batch 4
        self.linear4 = nn.Linear(2048, 2048)
        self.relu4 = nn.ReLU()
        # batch 5 output
        self.linearOut = nn.Linear(2048, output_dim)

    def forward(self, x):
        # reshape data to work with model
        out = x.reshape(-1, self.input_size)
        # batch 1
        out = self.linear1(out)
        out = self.relu1(out)
        # batch 2
        out = self.linear2(out)
        out = self.relu2(out)
        # batch 3
        out = self.linear3(out)
        out = self.relu3(out)
        # batch 4
        out = self.linear4(out)
        out = self.relu4(out)
        # batch 5 output
        out = self.linearOut(out)
        return out

# %%
# 3.2 Convolutional Neural Network

class MyCNN(nn.Module):
    def __init__(self, model_type, output_dim):
        super(MyCNN, self).__init__()
        # store model type
        self.model_type = model_type
        # batch 1:
        self.conv1 = nn.Conv2d(1, 128, kernel_size=3)
        self.relu1 = nn.ReLU()
        self.pool1 = nn.MaxPool2d(kernel_size=2)
        # batch 2
        self.conv2 = nn.Conv2d(128, 128, kernel_size=3)
        self.relu2 = nn.ReLU()
        self.pool2 = nn.MaxPool2d(kernel_size=2)
        # batch 3
        self.flatten = nn.Flatten()
        self.linear3 = nn.Linear(1024, 1024)
        self.relu3 = nn.ReLU()
        # batch 4
        self.linear4 = nn.Linear(1024, 1024)
        self.relu4 = nn.ReLU()
        # batch 5
        self.linear5 = nn.Linear(1024, output_dim)
        
    def forward(self, x):
        # reshape input
        x = x[:, None, :, :]
        # layer 1
        out = self.conv1(x)
        out = self.relu1(out)
        out = self.pool1(out)
        # layer 2
        out = self.conv2(out)
        out = self.relu2(out)
        out = self.pool2(out)
        # layer 3
        out = self.flatten(out)
        out = self.linear3(out)
        out = self.relu3(out)
        # layer 4
        out = self.linear4(out)
        out = self.relu4(out)
        #layer 5
        out = self.linear5(out)
        return out

# %%
# 4. Instantiate the model, loss function, and optimizer

total_examples = train_feats.shape[0]
input_size =  train_feats.shape[1] * train_feats.shape[2]
hidden_dim = 1000
output_size = 48

print ("examples: ", total_examples)
print ("input_size: ", input_size)
print ("output_size: ", output_size)


model = MyFFNN("FFNN", input_size, output_size)
#model = MyCNN("CNN", output_size)

model = model.to(device)
print ("model.device: ", next(model.parameters()).device)

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr = 0.001, momentum = 0.9)
# Out:
# examples:  44730
# input_size:  440
# output_size:  48
# model.device:  cuda:0

# %%
#  6. Evaluate the model on the held-out test data.

def test_network(model, test_loader):
    correct = 0
    total = 0
    with torch.no_grad():
        for data in test_loader:
            inputs, labels = data
            outputs = model(inputs)
            _, predicted = torch.max(outputs.data, 1)

            total += labels.size(0)
            correct += (predicted == labels).sum().item()
    return 100 * correct / total

# %%
# 7. determine accuracy for each phoneme individually

def compare_lists(list1, list2):
    return [x == y for x, y in zip(list1, list2)]

# https://www.geeksforgeeks.org/python-program-to-sort-a-list-of-tuples-by-second-item/
def sort_tuple_list(tuple_list):
    # reverse = None (Sorts in Ascending order)
    # key is set to sort using second element of
    # sublist lambda has been used
    tuple_list.sort(key = lambda x: x[0])
    return tuple_list

def calculate_phoneme_accuracy(myModel, test_loader):
    correct_list = [0] * 48
    total_list = [0] * 48
    phoneme_accuracy = [0.0] * 48
    with torch.no_grad():
        for data in test_loader:
            # get input data and labels
            inputs, labels = data
            # calculate predictions
            outputs = myModel(inputs)
            _, predicted = torch.max(outputs.data, 1)
            # determine which are correct
            correct = compare_lists(labels, predicted)
            # update lists
            for i in range(len(labels)):
                total_list[labels[i]] += 1
                if (correct[i]):
                    correct_list[labels[i]] += 1
                
    for i in range(48):
        if (total_list[i] != 0):
            phoneme_accuracy[i] = correct_list[i] / total_list[i]
                    
    # print ("total_list: ", total_list)
    # print ("correct_list: ", correct_list)
    # print ("phoneme_accuracy: ", phoneme_accuracy)
    
    return phoneme_accuracy

# %%
# 8. print out statistics and plots

def print_stats(myModel, iteration_list, accuracy_list, loss_list):
    # final accuracy plot        
    plt.plot(iteration_list, accuracy_list)
    plt.title("accuracy over time")
    plt.xlabel("iterations")
    plt.ylabel("accuracy")
    plt.show()
    
    # final loss plot        
    plt.plot(iteration_list, loss_list)
    plt.title("loss over time")
    plt.xlabel("iterations")
    plt.ylabel("loss")
    plt.show()
    
    # calculate phoneme accuracy        
    phoneme_accuracy = calculate_phoneme_accuracy(myModel, test_loader)
    # create phoneme and label list
    phoneme_accuracy_labeled = []
    for i in range(48):
        phoneme_accuracy_labeled.append([phoneme_accuracy[i], phone_labels[i]])
    phoneme_accuracy_labeled = sort_tuple_list(phoneme_accuracy_labeled)
    # split back into two
    a, b = zip(*phoneme_accuracy_labeled)
    
    # https://www.geeksforgeeks.org/bar-plot-in-matplotlib/
    # creating the bar plot
    fig, ax = plt.subplots(figsize =(16, 16))
    # Horizontal Bar Plot
    ax.barh(b, a)
    # Add padding between axes and labels
    ax.xaxis.set_tick_params(pad = 5)
    ax.yaxis.set_tick_params(pad = 5)
    # Add x, y gridlines
    ax.grid(visible = True, color ='grey', linestyle ='-.', linewidth = 0.5, alpha = 0.5)
    # Show top values
    ax.invert_yaxis()
    # Add annotation to bars
    for i in ax.patches:
        plt.text(i.get_width(), i.get_y() + 0.6, str(round((i.get_width()), 4)), fontsize = 10, fontweight ='bold', color ='grey')
    # Add Plot Title
    ax.set_title('accuracy of each phoneme', loc ='left')
    # Show Plot
    # Remove x, y Ticks
    plt.xlabel("accuracy")
    plt.ylabel("phonemes")
    plt.show()

# %%
# 5. Train the model with stochastic gradient descent, iterating over the training dataset several times

def train_network(epochs, iterations, current_model, train_loader, criterion, optimizer, print_iteration):
    
    startTime = time.time()

    print ("device name: ", torch.cuda.get_device_name(0))
    print ("model.type: ", current_model.model_type)
    print ("model.device: ", next(current_model.parameters()).device)
    
    current_iteration = 0
    
    # lists for data collection
    iteration_list = []
    accuracy_list = []
    loss_list = []

    for epoch in range(epochs):
        print ("epoch: ", epoch)
        for i, (inputs, labels) in enumerate(train_loader, 0):
            current_iteration = i + ((epoch) * iterations)
            # forward pass
            outputs = current_model(inputs)
            loss = criterion(outputs, labels)
            # backward pass and optimize
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            # calculate accuracy
            if current_iteration % 100 == 0:  
                test_accuracy = test_network(current_model, test_loader)
                accuracy_list.append(test_accuracy)
                iteration_list.append(current_iteration)
                loss_list.append(loss.item())
            # print stats during training
            if current_iteration % print_iteration == 0:
                test_accuracy = test_network(current_model, test_loader)
                print(f'\t iteration: {current_iteration}\t loss: {loss.item():.3f}\t accuracy: {test_accuracy:.3f} %')
               
            current_iteration += 1         
    # print out stats
    print_stats(current_model, iteration_list, accuracy_list, loss_list)
    print ("time elapsed: ", round((time.time() - startTime), 2), " sec")

# %%
# all together now!

epochs = 100
iterations = total_examples / batch_size
iterations = int(iterations)
input_size =  train_feats.shape[1] * train_feats.shape[2]
output_size = 48

print ("epochs: ", epochs)
print ("total_examples: ", total_examples)
print ("iterations per epoch: ", iterations)
print ("batch_size: ", batch_size)
print ("input_size: ", input_size)
print ("output_size: ", output_size)
print ("---------------------------------")


# feed forward
myModel = MyFFNN("FFNN", input_size, output_size)
myModel = myModel.to(device)
myCriterion = nn.CrossEntropyLoss()
mOptimizer = optim.SGD(myModel.parameters(), lr = 0.001, momentum = 0.9)
train_network(epochs, iterations, myModel, train_loader, myCriterion, mOptimizer, int(iterations / 3))

print ("---------------------------------")

# convolutional
myModel = MyCNN("CNN", output_size)
myModel = myModel.to(device)
myCriterion = nn.CrossEntropyLoss()
mOptimizer = optim.SGD(myModel.parameters(), lr = 0.001, momentum = 0.9)
train_network(epochs, iterations, myModel, train_loader, myCriterion, mOptimizer, int(iterations / 3))
# Out:
# epochs:  100
# total_examples:  44730
# iterations per epoch:  698
# batch_size:  64
# input_size:  440
# output_size:  48
# ---------------------------------
# device name:  NVIDIA GeForce GTX 1660 Ti
# model.type:  FFNN
# model.device:  cuda:0
# epoch:  0
# 	 iteration: 0	 loss: 4.082	 accuracy: 1.844 %
# 	 iteration: 232	 loss: 1.632	 accuracy: 43.285 %
# 	 iteration: 464	 loss: 1.518	 accuracy: 48.502 %
# 	 iteration: 696	 loss: 1.505	 accuracy: 52.755 %
# epoch:  1
# 	 iteration: 928	 loss: 1.534	 accuracy: 54.096 %
# 	 iteration: 1160	 loss: 1.270	 accuracy: 53.342 %
# 	 iteration: 1392	 loss: 1.515	 accuracy: 54.724 %
# epoch:  2
# 	 iteration: 1624	 loss: 1.522	 accuracy: 55.479 %
# 	 iteration: 1856	 loss: 1.249	 accuracy: 57.113 %
# 	 iteration: 2088	 loss: 1.532	 accuracy: 59.145 %
# epoch:  3
# 	 iteration: 2320	 loss: 1.562	 accuracy: 59.627 %
# 	 iteration: 2552	 loss: 1.243	 accuracy: 59.585 %
# 	 iteration: 2784	 loss: 1.134	 accuracy: 60.109 %
# epoch:  4
# 	 iteration: 3016	 loss: 1.163	 accuracy: 60.256 %
# 	 iteration: 3248	 loss: 1.135	 accuracy: 61.010 %
# 	 iteration: 3480	 loss: 1.087	 accuracy: 61.953 %
# epoch:  5
# 	 iteration: 3712	 loss: 1.052	 accuracy: 60.654 %
# 	 iteration: 3944	 loss: 0.813	 accuracy: 61.031 %
# 	 iteration: 4176	 loss: 1.059	 accuracy: 60.989 %
# epoch:  6
# 	 iteration: 4408	 loss: 1.008	 accuracy: 61.827 %
# 	 iteration: 4640	 loss: 0.890	 accuracy: 63.608 %
# 	 iteration: 4872	 loss: 1.321	 accuracy: 61.827 %
# epoch:  7
# 	 iteration: 5104	 loss: 0.930	 accuracy: 62.225 %
# 	 iteration: 5336	 loss: 0.978	 accuracy: 62.330 %
# 	 iteration: 5568	 loss: 1.005	 accuracy: 62.686 %
# epoch:  8
# 	 iteration: 5800	 loss: 1.033	 accuracy: 63.734 %
# 	 iteration: 6032	 loss: 1.197	 accuracy: 63.168 %
# 	 iteration: 6264	 loss: 0.974	 accuracy: 61.743 %
# epoch:  9
# 	 iteration: 6496	 loss: 0.833	 accuracy: 62.895 %
# 	 iteration: 6728	 loss: 0.943	 accuracy: 62.854 %
# 	 iteration: 6960	 loss: 0.614	 accuracy: 63.943 %
# epoch:  10
# 	 iteration: 7192	 loss: 0.606	 accuracy: 63.671 %
# 	 iteration: 7424	 loss: 0.988	 accuracy: 63.314 %
# 	 iteration: 7656	 loss: 0.867	 accuracy: 61.617 %
# epoch:  11
# 	 iteration: 7888	 loss: 0.874	 accuracy: 64.362 %
# 	 iteration: 8120	 loss: 0.727	 accuracy: 63.901 %
# 	 iteration: 8352	 loss: 0.937	 accuracy: 65.032 %
# epoch:  12
# 	 iteration: 8584	 loss: 0.756	 accuracy: 64.572 %
# 	 iteration: 8816	 loss: 1.029	 accuracy: 64.739 %
# 	 iteration: 9048	 loss: 0.961	 accuracy: 62.854 %
# epoch:  13
# 	 iteration: 9280	 loss: 0.822	 accuracy: 63.964 %
# 	 iteration: 9512	 loss: 0.647	 accuracy: 65.221 %
# 	 iteration: 9744	 loss: 0.548	 accuracy: 65.368 %
# epoch:  14
# 	 iteration: 9976	 loss: 0.545	 accuracy: 63.126 %
# 	 iteration: 10208	 loss: 0.802	 accuracy: 66.059 %
# 	 iteration: 10440	 loss: 0.541	 accuracy: 64.006 %
# epoch:  15
# 	 iteration: 10672	 loss: 0.542	 accuracy: 65.326 %
# 	 iteration: 10904	 loss: 0.626	 accuracy: 65.535 %
# 	 iteration: 11136	 loss: 0.786	 accuracy: 64.823 %
# epoch:  16
# 	 iteration: 11368	 loss: 0.798	 accuracy: 65.158 %
# 	 iteration: 11600	 loss: 0.604	 accuracy: 65.012 %
# 	 iteration: 11832	 loss: 0.624	 accuracy: 65.326 %
# epoch:  17
# 	 iteration: 12064	 loss: 0.680	 accuracy: 63.775 %
# 	 iteration: 12296	 loss: 0.571	 accuracy: 64.278 %
# 	 iteration: 12528	 loss: 0.829	 accuracy: 66.185 %
# epoch:  18
# 	 iteration: 12760	 loss: 0.649	 accuracy: 64.844 %
# 	 iteration: 12992	 loss: 0.605	 accuracy: 64.802 %
# 	 iteration: 13224	 loss: 0.708	 accuracy: 65.263 %
# epoch:  19
# 	 iteration: 13456	 loss: 0.467	 accuracy: 66.080 %
# 	 iteration: 13688	 loss: 0.498	 accuracy: 64.970 %
# 	 iteration: 13920	 loss: 0.611	 accuracy: 65.305 %
# epoch:  20
# 	 iteration: 14152	 loss: 0.464	 accuracy: 65.095 %
# 	 iteration: 14384	 loss: 0.482	 accuracy: 65.871 %
# 	 iteration: 14616	 loss: 0.623	 accuracy: 65.032 %
# epoch:  21
# 	 iteration: 14848	 loss: 0.521	 accuracy: 65.221 %
# 	 iteration: 15080	 loss: 0.573	 accuracy: 65.472 %
# 	 iteration: 15312	 loss: 0.498	 accuracy: 64.949 %
# epoch:  22
# 	 iteration: 15544	 loss: 0.534	 accuracy: 65.724 %
# 	 iteration: 15776	 loss: 0.654	 accuracy: 65.284 %
# 	 iteration: 16008	 loss: 0.565	 accuracy: 65.116 %
# epoch:  23
# 	 iteration: 16240	 loss: 0.574	 accuracy: 66.457 %
# 	 iteration: 16472	 loss: 0.542	 accuracy: 65.493 %
# 	 iteration: 16704	 loss: 0.507	 accuracy: 66.248 %
# epoch:  24
# 	 iteration: 16936	 loss: 0.282	 accuracy: 66.059 %
# 	 iteration: 17168	 loss: 0.445	 accuracy: 65.787 %
# 	 iteration: 17400	 loss: 0.595	 accuracy: 65.535 %
# epoch:  25
# 	 iteration: 17632	 loss: 0.349	 accuracy: 66.457 %
# 	 iteration: 17864	 loss: 0.464	 accuracy: 65.053 %
# 	 iteration: 18096	 loss: 0.454	 accuracy: 66.499 %
# epoch:  26
# 	 iteration: 18328	 loss: 0.519	 accuracy: 65.410 %
# 	 iteration: 18560	 loss: 0.303	 accuracy: 64.718 %
# 	 iteration: 18792	 loss: 0.534	 accuracy: 66.080 %
# epoch:  27
# 	 iteration: 19024	 loss: 0.208	 accuracy: 65.451 %
# 	 iteration: 19256	 loss: 0.431	 accuracy: 66.541 %
# 	 iteration: 19488	 loss: 0.586	 accuracy: 65.891 %
# epoch:  28
# 	 iteration: 19720	 loss: 0.278	 accuracy: 65.200 %
# 	 iteration: 19952	 loss: 0.348	 accuracy: 66.059 %
# 	 iteration: 20184	 loss: 0.348	 accuracy: 66.604 %
# epoch:  29
# 	 iteration: 20416	 loss: 0.387	 accuracy: 66.164 %
# 	 iteration: 20648	 loss: 0.543	 accuracy: 64.320 %
# 	 iteration: 20880	 loss: 0.333	 accuracy: 66.122 %
# epoch:  30
# 	 iteration: 21112	 loss: 0.165	 accuracy: 65.703 %
# 	 iteration: 21344	 loss: 0.433	 accuracy: 66.080 %
# 	 iteration: 21576	 loss: 0.283	 accuracy: 66.017 %
# epoch:  31
# 	 iteration: 21808	 loss: 0.139	 accuracy: 66.625 %
# 	 iteration: 22040	 loss: 0.309	 accuracy: 64.592 %
# 	 iteration: 22272	 loss: 0.360	 accuracy: 64.613 %
# epoch:  32
# 	 iteration: 22504	 loss: 0.116	 accuracy: 66.101 %
# 	 iteration: 22736	 loss: 0.296	 accuracy: 65.074 %
# 	 iteration: 22968	 loss: 0.304	 accuracy: 66.185 %
# epoch:  33
# 	 iteration: 23200	 loss: 0.151	 accuracy: 66.478 %
# 	 iteration: 23432	 loss: 0.151	 accuracy: 65.954 %
# 	 iteration: 23664	 loss: 0.323	 accuracy: 64.530 %
# epoch:  34
# 	 iteration: 23896	 loss: 0.190	 accuracy: 66.310 %
# 	 iteration: 24128	 loss: 0.207	 accuracy: 65.766 %
# 	 iteration: 24360	 loss: 0.202	 accuracy: 65.095 %
# epoch:  35
# 	 iteration: 24592	 loss: 0.139	 accuracy: 65.389 %
# 	 iteration: 24824	 loss: 0.201	 accuracy: 65.745 %
# 	 iteration: 25056	 loss: 0.245	 accuracy: 65.912 %
# epoch:  36
# 	 iteration: 25288	 loss: 0.103	 accuracy: 66.918 %
# 	 iteration: 25520	 loss: 0.106	 accuracy: 65.766 %
# 	 iteration: 25752	 loss: 0.181	 accuracy: 65.556 %
# epoch:  37
# 	 iteration: 25984	 loss: 0.082	 accuracy: 67.065 %
# 	 iteration: 26216	 loss: 0.125	 accuracy: 64.739 %
# 	 iteration: 26448	 loss: 0.202	 accuracy: 65.158 %
# epoch:  38
# 	 iteration: 26680	 loss: 0.160	 accuracy: 66.415 %
# 	 iteration: 26912	 loss: 0.139	 accuracy: 66.290 %
# 	 iteration: 27144	 loss: 0.094	 accuracy: 65.871 %
# epoch:  39
# 	 iteration: 27376	 loss: 0.127	 accuracy: 66.185 %
# 	 iteration: 27608	 loss: 0.089	 accuracy: 66.080 %
# 	 iteration: 27840	 loss: 0.129	 accuracy: 65.535 %
# epoch:  40
# 	 iteration: 28072	 loss: 0.089	 accuracy: 66.981 %
# 	 iteration: 28304	 loss: 0.111	 accuracy: 66.876 %
# 	 iteration: 28536	 loss: 0.067	 accuracy: 64.530 %
# epoch:  41
# 	 iteration: 28768	 loss: 0.052	 accuracy: 66.394 %
# 	 iteration: 29000	 loss: 0.161	 accuracy: 66.143 %
# 	 iteration: 29232	 loss: 0.024	 accuracy: 66.206 %
# epoch:  42
# 	 iteration: 29464	 loss: 0.029	 accuracy: 67.547 %
# 	 iteration: 29696	 loss: 0.070	 accuracy: 66.646 %
# 	 iteration: 29928	 loss: 0.045	 accuracy: 65.598 %
# epoch:  43
# 	 iteration: 30160	 loss: 0.168	 accuracy: 66.646 %
# 	 iteration: 30392	 loss: 0.075	 accuracy: 66.290 %
# 	 iteration: 30624	 loss: 0.089	 accuracy: 66.520 %
# epoch:  44
# 	 iteration: 30856	 loss: 0.026	 accuracy: 67.149 %
# 	 iteration: 31088	 loss: 0.026	 accuracy: 67.316 %
# 	 iteration: 31320	 loss: 0.078	 accuracy: 66.248 %
# epoch:  45
# 	 iteration: 31552	 loss: 0.032	 accuracy: 66.834 %
# 	 iteration: 31784	 loss: 0.024	 accuracy: 67.379 %
# 	 iteration: 32016	 loss: 0.070	 accuracy: 66.688 %
# epoch:  46
# 	 iteration: 32248	 loss: 0.045	 accuracy: 67.463 %
# 	 iteration: 32480	 loss: 0.044	 accuracy: 67.295 %
# 	 iteration: 32712	 loss: 0.165	 accuracy: 65.514 %
# epoch:  47
# 	 iteration: 32944	 loss: 0.035	 accuracy: 67.128 %
# 	 iteration: 33176	 loss: 0.028	 accuracy: 67.274 %
# 	 iteration: 33408	 loss: 0.192	 accuracy: 66.310 %
# epoch:  48
# 	 iteration: 33640	 loss: 0.010	 accuracy: 67.484 %
# 	 iteration: 33872	 loss: 0.012	 accuracy: 67.714 %
# 	 iteration: 34104	 loss: 0.072	 accuracy: 67.086 %
# epoch:  49
# 	 iteration: 34336	 loss: 0.096	 accuracy: 67.107 %
# 	 iteration: 34568	 loss: 0.095	 accuracy: 66.185 %
# 	 iteration: 34800	 loss: 0.024	 accuracy: 66.625 %
# epoch:  50
# 	 iteration: 35032	 loss: 0.009	 accuracy: 67.526 %
# 	 iteration: 35264	 loss: 0.022	 accuracy: 66.813 %
# 	 iteration: 35496	 loss: 0.075	 accuracy: 67.002 %
# epoch:  51
# 	 iteration: 35728	 loss: 0.028	 accuracy: 67.211 %
# 	 iteration: 35960	 loss: 0.023	 accuracy: 66.876 %
# 	 iteration: 36192	 loss: 0.027	 accuracy: 66.562 %
# epoch:  52
# 	 iteration: 36424	 loss: 0.017	 accuracy: 67.211 %
# 	 iteration: 36656	 loss: 0.006	 accuracy: 67.526 %
# 	 iteration: 36888	 loss: 0.062	 accuracy: 67.735 %
# epoch:  53
# 	 iteration: 37120	 loss: 0.006	 accuracy: 67.714 %
# 	 iteration: 37352	 loss: 0.008	 accuracy: 67.568 %
# 	 iteration: 37584	 loss: 0.003	 accuracy: 67.630 %
# epoch:  54
# 	 iteration: 37816	 loss: 0.013	 accuracy: 67.903 %
# 	 iteration: 38048	 loss: 0.003	 accuracy: 68.091 %
# 	 iteration: 38280	 loss: 0.005	 accuracy: 67.044 %
# epoch:  55
# 	 iteration: 38512	 loss: 0.008	 accuracy: 67.232 %
# 	 iteration: 38744	 loss: 0.004	 accuracy: 67.358 %
# 	 iteration: 38976	 loss: 0.016	 accuracy: 67.651 %
# epoch:  56
# 	 iteration: 39208	 loss: 0.002	 accuracy: 67.777 %
# 	 iteration: 39440	 loss: 0.003	 accuracy: 67.651 %
# 	 iteration: 39672	 loss: 0.003	 accuracy: 67.400 %
# epoch:  57
# 	 iteration: 39904	 loss: 0.005	 accuracy: 67.987 %
# 	 iteration: 40136	 loss: 0.003	 accuracy: 67.651 %
# 	 iteration: 40368	 loss: 0.003	 accuracy: 67.609 %
# epoch:  58
# 	 iteration: 40600	 loss: 0.002	 accuracy: 67.882 %
# 	 iteration: 40832	 loss: 0.004	 accuracy: 68.070 %
# 	 iteration: 41064	 loss: 0.017	 accuracy: 68.008 %
# epoch:  59
# 	 iteration: 41296	 loss: 0.032	 accuracy: 67.609 %
# 	 iteration: 41528	 loss: 0.028	 accuracy: 66.101 %
# 	 iteration: 41760	 loss: 0.100	 accuracy: 64.739 %
# epoch:  60
# 	 iteration: 41992	 loss: 0.205	 accuracy: 65.808 %
# 	 iteration: 42224	 loss: 0.014	 accuracy: 66.143 %
# 	 iteration: 42456	 loss: 0.021	 accuracy: 66.960 %
# epoch:  61
# 	 iteration: 42688	 loss: 0.005	 accuracy: 67.526 %
# 	 iteration: 42920	 loss: 0.005	 accuracy: 67.484 %
# 	 iteration: 43152	 loss: 0.018	 accuracy: 67.002 %
# epoch:  62
# 	 iteration: 43384	 loss: 0.002	 accuracy: 67.777 %
# 	 iteration: 43616	 loss: 0.003	 accuracy: 67.987 %
# 	 iteration: 43848	 loss: 0.004	 accuracy: 67.693 %
# epoch:  63
# 	 iteration: 44080	 loss: 0.003	 accuracy: 67.609 %
# 	 iteration: 44312	 loss: 0.004	 accuracy: 68.070 %
# 	 iteration: 44544	 loss: 0.002	 accuracy: 67.777 %
# epoch:  64
# 	 iteration: 44776	 loss: 0.002	 accuracy: 67.882 %
# 	 iteration: 45008	 loss: 0.002	 accuracy: 67.798 %
# 	 iteration: 45240	 loss: 0.002	 accuracy: 68.259 %
# epoch:  65
# 	 iteration: 45472	 loss: 0.002	 accuracy: 68.406 %
# 	 iteration: 45704	 loss: 0.002	 accuracy: 67.966 %
# 	 iteration: 45936	 loss: 0.010	 accuracy: 67.630 %
# epoch:  66
# 	 iteration: 46168	 loss: 0.002	 accuracy: 68.091 %
# 	 iteration: 46400	 loss: 0.002	 accuracy: 67.945 %
# 	 iteration: 46632	 loss: 0.008	 accuracy: 67.945 %
# epoch:  67
# 	 iteration: 46864	 loss: 0.003	 accuracy: 67.714 %
# 	 iteration: 47096	 loss: 0.001	 accuracy: 67.819 %
# 	 iteration: 47328	 loss: 0.003	 accuracy: 68.070 %
# epoch:  68
# 	 iteration: 47560	 loss: 0.002	 accuracy: 67.756 %
# 	 iteration: 47792	 loss: 0.001	 accuracy: 67.861 %
# 	 iteration: 48024	 loss: 0.002	 accuracy: 68.133 %
# epoch:  69
# 	 iteration: 48256	 loss: 0.002	 accuracy: 67.840 %
# 	 iteration: 48488	 loss: 0.002	 accuracy: 67.924 %
# 	 iteration: 48720	 loss: 0.003	 accuracy: 67.861 %
# epoch:  70
# 	 iteration: 48952	 loss: 0.001	 accuracy: 67.882 %
# 	 iteration: 49184	 loss: 0.001	 accuracy: 67.735 %
# 	 iteration: 49416	 loss: 0.001	 accuracy: 67.672 %
# epoch:  71
# 	 iteration: 49648	 loss: 0.002	 accuracy: 67.714 %
# 	 iteration: 49880	 loss: 0.007	 accuracy: 67.505 %
# 	 iteration: 50112	 loss: 0.001	 accuracy: 67.735 %
# epoch:  72
# 	 iteration: 50344	 loss: 0.006	 accuracy: 67.589 %
# 	 iteration: 50576	 loss: 0.002	 accuracy: 67.672 %
# 	 iteration: 50808	 loss: 0.009	 accuracy: 68.028 %
# epoch:  73
# 	 iteration: 51040	 loss: 0.001	 accuracy: 67.756 %
# 	 iteration: 51272	 loss: 0.002	 accuracy: 67.547 %
# 	 iteration: 51504	 loss: 0.001	 accuracy: 67.903 %
# epoch:  74
# 	 iteration: 51736	 loss: 0.000	 accuracy: 68.008 %
# 	 iteration: 51968	 loss: 0.001	 accuracy: 68.070 %
# 	 iteration: 52200	 loss: 0.001	 accuracy: 67.945 %
# epoch:  75
# 	 iteration: 52432	 loss: 0.001	 accuracy: 68.049 %
# 	 iteration: 52664	 loss: 0.001	 accuracy: 67.945 %
# 	 iteration: 52896	 loss: 0.008	 accuracy: 67.756 %
# epoch:  76
# 	 iteration: 53128	 loss: 0.001	 accuracy: 67.924 %
# 	 iteration: 53360	 loss: 0.001	 accuracy: 67.924 %
# 	 iteration: 53592	 loss: 0.001	 accuracy: 67.966 %
# epoch:  77
# 	 iteration: 53824	 loss: 0.075	 accuracy: 68.091 %
# 	 iteration: 54056	 loss: 0.001	 accuracy: 68.259 %
# 	 iteration: 54288	 loss: 0.001	 accuracy: 67.819 %
# epoch:  78
# 	 iteration: 54520	 loss: 0.001	 accuracy: 67.463 %
# 	 iteration: 54752	 loss: 0.001	 accuracy: 67.903 %
# 	 iteration: 54984	 loss: 0.001	 accuracy: 67.945 %
# epoch:  79
# 	 iteration: 55216	 loss: 0.001	 accuracy: 67.756 %
# 	 iteration: 55448	 loss: 0.001	 accuracy: 67.798 %
# 	 iteration: 55680	 loss: 0.001	 accuracy: 67.924 %
# epoch:  80
# 	 iteration: 55912	 loss: 0.001	 accuracy: 67.840 %
# 	 iteration: 56144	 loss: 0.001	 accuracy: 68.049 %
# 	 iteration: 56376	 loss: 0.001	 accuracy: 67.882 %
# epoch:  81
# 	 iteration: 56608	 loss: 0.001	 accuracy: 67.945 %
# 	 iteration: 56840	 loss: 0.001	 accuracy: 67.924 %
# 	 iteration: 57072	 loss: 0.001	 accuracy: 67.882 %
# epoch:  82
# 	 iteration: 57304	 loss: 0.001	 accuracy: 67.987 %
# 	 iteration: 57536	 loss: 0.001	 accuracy: 67.924 %
# 	 iteration: 57768	 loss: 0.001	 accuracy: 67.966 %
# epoch:  83
# 	 iteration: 58000	 loss: 0.001	 accuracy: 67.945 %
# 	 iteration: 58232	 loss: 0.001	 accuracy: 68.008 %
# 	 iteration: 58464	 loss: 0.001	 accuracy: 67.987 %
# epoch:  84
# 	 iteration: 58696	 loss: 0.001	 accuracy: 67.882 %
# 	 iteration: 58928	 loss: 0.001	 accuracy: 67.882 %
# 	 iteration: 59160	 loss: 0.000	 accuracy: 67.861 %
# epoch:  85
# 	 iteration: 59392	 loss: 0.000	 accuracy: 68.133 %
# 	 iteration: 59624	 loss: 0.001	 accuracy: 68.049 %
# 	 iteration: 59856	 loss: 0.001	 accuracy: 67.547 %
# epoch:  86
# 	 iteration: 60088	 loss: 0.001	 accuracy: 67.651 %
# 	 iteration: 60320	 loss: 0.540	 accuracy: 60.842 %
# 	 iteration: 60552	 loss: 0.077	 accuracy: 65.284 %
# epoch:  87
# 	 iteration: 60784	 loss: 0.038	 accuracy: 65.472 %
# 	 iteration: 61016	 loss: 0.016	 accuracy: 66.457 %
# 	 iteration: 61248	 loss: 0.005	 accuracy: 66.939 %
# epoch:  88
# 	 iteration: 61480	 loss: 0.002	 accuracy: 67.379 %
# 	 iteration: 61712	 loss: 0.003	 accuracy: 67.442 %
# 	 iteration: 61944	 loss: 0.003	 accuracy: 67.484 %
# epoch:  89
# 	 iteration: 62176	 loss: 0.002	 accuracy: 67.421 %
# 	 iteration: 62408	 loss: 0.002	 accuracy: 67.589 %
# 	 iteration: 62640	 loss: 0.001	 accuracy: 67.630 %
# epoch:  90
# 	 iteration: 62872	 loss: 0.002	 accuracy: 67.630 %
# 	 iteration: 63104	 loss: 0.002	 accuracy: 67.840 %
# 	 iteration: 63336	 loss: 0.002	 accuracy: 67.714 %
# epoch:  91
# 	 iteration: 63568	 loss: 0.002	 accuracy: 67.316 %
# 	 iteration: 63800	 loss: 0.003	 accuracy: 67.609 %
# 	 iteration: 64032	 loss: 0.001	 accuracy: 67.840 %
# epoch:  92
# 	 iteration: 64264	 loss: 0.001	 accuracy: 67.651 %
# 	 iteration: 64496	 loss: 0.001	 accuracy: 67.735 %
# 	 iteration: 64728	 loss: 0.001	 accuracy: 67.672 %
# epoch:  93
# 	 iteration: 64960	 loss: 0.001	 accuracy: 67.651 %
# 	 iteration: 65192	 loss: 0.001	 accuracy: 67.630 %
# 	 iteration: 65424	 loss: 0.002	 accuracy: 67.547 %
# epoch:  94
# 	 iteration: 65656	 loss: 0.001	 accuracy: 67.693 %
# 	 iteration: 65888	 loss: 0.001	 accuracy: 67.819 %
# 	 iteration: 66120	 loss: 0.003	 accuracy: 67.630 %
# epoch:  95
# 	 iteration: 66352	 loss: 0.001	 accuracy: 67.861 %
# 	 iteration: 66584	 loss: 0.001	 accuracy: 67.903 %
# 	 iteration: 66816	 loss: 0.001	 accuracy: 67.756 %
# epoch:  96
# 	 iteration: 67048	 loss: 0.001	 accuracy: 67.693 %
# 	 iteration: 67280	 loss: 0.001	 accuracy: 67.735 %
# 	 iteration: 67512	 loss: 0.001	 accuracy: 67.882 %
# epoch:  97
# 	 iteration: 67744	 loss: 0.001	 accuracy: 67.861 %
# 	 iteration: 67976	 loss: 0.001	 accuracy: 67.630 %
# 	 iteration: 68208	 loss: 0.001	 accuracy: 67.714 %
# epoch:  98
# 	 iteration: 68440	 loss: 0.001	 accuracy: 67.756 %
# 	 iteration: 68672	 loss: 0.001	 accuracy: 67.882 %
# 	 iteration: 68904	 loss: 0.001	 accuracy: 67.882 %
# epoch:  99
# 	 iteration: 69136	 loss: 0.001	 accuracy: 67.777 %
# 	 iteration: 69368	 loss: 0.002	 accuracy: 67.819 %
# 	 iteration: 69600	 loss: 0.001	 accuracy: 67.861 %
# time elapsed:  8642.98  sec
# ---------------------------------
# device name:  NVIDIA GeForce GTX 1660 Ti
# model.type:  CNN
# model.device:  cuda:0
# epoch:  0
# 	 iteration: 0	 loss: 4.288	 accuracy: 2.305 %
# 	 iteration: 232	 loss: 2.068	 accuracy: 35.282 %
# 	 iteration: 464	 loss: 1.709	 accuracy: 43.809 %
# 	 iteration: 696	 loss: 1.247	 accuracy: 50.765 %
# epoch:  1
# 	 iteration: 928	 loss: 1.626	 accuracy: 50.576 %
# 	 iteration: 1160	 loss: 1.823	 accuracy: 54.201 %
# 	 iteration: 1392	 loss: 1.193	 accuracy: 53.635 %
# epoch:  2
# 	 iteration: 1624	 loss: 1.149	 accuracy: 56.820 %
# 	 iteration: 1856	 loss: 1.510	 accuracy: 55.814 %
# 	 iteration: 2088	 loss: 1.046	 accuracy: 58.810 %
# epoch:  3
# 	 iteration: 2320	 loss: 1.466	 accuracy: 57.469 %
# 	 iteration: 2552	 loss: 1.269	 accuracy: 59.376 %
# 	 iteration: 2784	 loss: 1.170	 accuracy: 59.103 %
# epoch:  4
# 	 iteration: 3016	 loss: 1.146	 accuracy: 60.507 %
# 	 iteration: 3248	 loss: 1.045	 accuracy: 60.046 %
# 	 iteration: 3480	 loss: 0.835	 accuracy: 61.408 %
# epoch:  5
# 	 iteration: 3712	 loss: 1.062	 accuracy: 62.497 %
# 	 iteration: 3944	 loss: 1.173	 accuracy: 61.911 %
# 	 iteration: 4176	 loss: 1.110	 accuracy: 61.932 %
# epoch:  6
# 	 iteration: 4408	 loss: 1.047	 accuracy: 63.000 %
# 	 iteration: 4640	 loss: 1.320	 accuracy: 63.273 %
# 	 iteration: 4872	 loss: 1.025	 accuracy: 64.132 %
# epoch:  7
# 	 iteration: 5104	 loss: 0.745	 accuracy: 63.692 %
# 	 iteration: 5336	 loss: 0.876	 accuracy: 63.587 %
# 	 iteration: 5568	 loss: 0.910	 accuracy: 62.958 %
# epoch:  8
# 	 iteration: 5800	 loss: 1.160	 accuracy: 64.383 %
# 	 iteration: 6032	 loss: 0.616	 accuracy: 63.985 %
# 	 iteration: 6264	 loss: 0.923	 accuracy: 63.922 %
# epoch:  9
# 	 iteration: 6496	 loss: 0.723	 accuracy: 64.153 %
# 	 iteration: 6728	 loss: 0.929	 accuracy: 64.655 %
# 	 iteration: 6960	 loss: 1.068	 accuracy: 65.661 %
# epoch:  10
# 	 iteration: 7192	 loss: 1.042	 accuracy: 65.766 %
# 	 iteration: 7424	 loss: 0.741	 accuracy: 65.347 %
# 	 iteration: 7656	 loss: 0.741	 accuracy: 65.451 %
# epoch:  11
# 	 iteration: 7888	 loss: 0.725	 accuracy: 65.368 %
# 	 iteration: 8120	 loss: 0.700	 accuracy: 65.682 %
# 	 iteration: 8352	 loss: 0.795	 accuracy: 65.640 %
# epoch:  12
# 	 iteration: 8584	 loss: 0.704	 accuracy: 65.493 %
# 	 iteration: 8816	 loss: 0.773	 accuracy: 64.802 %
# 	 iteration: 9048	 loss: 0.644	 accuracy: 65.682 %
# epoch:  13
# 	 iteration: 9280	 loss: 0.650	 accuracy: 66.185 %
# 	 iteration: 9512	 loss: 0.801	 accuracy: 65.263 %
# 	 iteration: 9744	 loss: 0.501	 accuracy: 66.792 %
# epoch:  14
# 	 iteration: 9976	 loss: 0.520	 accuracy: 65.535 %
# 	 iteration: 10208	 loss: 0.434	 accuracy: 65.682 %
# 	 iteration: 10440	 loss: 0.804	 accuracy: 66.373 %
# epoch:  15
# 	 iteration: 10672	 loss: 0.375	 accuracy: 64.697 %
# 	 iteration: 10904	 loss: 0.553	 accuracy: 65.891 %
# 	 iteration: 11136	 loss: 0.695	 accuracy: 65.012 %
# epoch:  16
# 	 iteration: 11368	 loss: 0.523	 accuracy: 65.871 %
# 	 iteration: 11600	 loss: 0.598	 accuracy: 65.808 %
# 	 iteration: 11832	 loss: 0.710	 accuracy: 65.514 %
# epoch:  17
# 	 iteration: 12064	 loss: 0.436	 accuracy: 65.661 %
# 	 iteration: 12296	 loss: 0.536	 accuracy: 64.928 %
# 	 iteration: 12528	 loss: 0.520	 accuracy: 65.263 %
# epoch:  18
# 	 iteration: 12760	 loss: 0.820	 accuracy: 66.499 %
# 	 iteration: 12992	 loss: 0.588	 accuracy: 65.598 %
# 	 iteration: 13224	 loss: 0.765	 accuracy: 65.116 %
# epoch:  19
# 	 iteration: 13456	 loss: 0.350	 accuracy: 65.598 %
# 	 iteration: 13688	 loss: 0.542	 accuracy: 65.703 %
# 	 iteration: 13920	 loss: 0.657	 accuracy: 64.760 %
# epoch:  20
# 	 iteration: 14152	 loss: 0.370	 accuracy: 64.697 %
# 	 iteration: 14384	 loss: 0.414	 accuracy: 64.886 %
# 	 iteration: 14616	 loss: 0.365	 accuracy: 64.928 %
# epoch:  21
# 	 iteration: 14848	 loss: 0.502	 accuracy: 65.514 %
# 	 iteration: 15080	 loss: 0.275	 accuracy: 65.850 %
# 	 iteration: 15312	 loss: 0.367	 accuracy: 65.137 %
# epoch:  22
# 	 iteration: 15544	 loss: 0.427	 accuracy: 65.472 %
# 	 iteration: 15776	 loss: 0.238	 accuracy: 64.949 %
# 	 iteration: 16008	 loss: 0.467	 accuracy: 64.949 %
# epoch:  23
# 	 iteration: 16240	 loss: 0.341	 accuracy: 65.954 %
# 	 iteration: 16472	 loss: 0.247	 accuracy: 65.431 %
# 	 iteration: 16704	 loss: 0.297	 accuracy: 64.592 %
# epoch:  24
# 	 iteration: 16936	 loss: 0.171	 accuracy: 65.179 %
# 	 iteration: 17168	 loss: 0.323	 accuracy: 64.928 %
# 	 iteration: 17400	 loss: 0.356	 accuracy: 64.446 %
# epoch:  25
# 	 iteration: 17632	 loss: 0.201	 accuracy: 65.158 %
# 	 iteration: 17864	 loss: 0.191	 accuracy: 63.671 %
# 	 iteration: 18096	 loss: 0.278	 accuracy: 65.535 %
# epoch:  26
# 	 iteration: 18328	 loss: 0.297	 accuracy: 65.912 %
# 	 iteration: 18560	 loss: 0.194	 accuracy: 63.775 %
# 	 iteration: 18792	 loss: 0.175	 accuracy: 64.634 %
# epoch:  27
# 	 iteration: 19024	 loss: 0.193	 accuracy: 65.012 %
# 	 iteration: 19256	 loss: 0.220	 accuracy: 65.410 %
# 	 iteration: 19488	 loss: 0.218	 accuracy: 64.299 %
# epoch:  28
# 	 iteration: 19720	 loss: 0.141	 accuracy: 64.760 %
# 	 iteration: 19952	 loss: 0.209	 accuracy: 65.410 %
# 	 iteration: 20184	 loss: 0.288	 accuracy: 64.257 %
# epoch:  29
# 	 iteration: 20416	 loss: 0.244	 accuracy: 65.493 %
# 	 iteration: 20648	 loss: 0.079	 accuracy: 64.718 %
# 	 iteration: 20880	 loss: 0.174	 accuracy: 65.012 %
# epoch:  30
# 	 iteration: 21112	 loss: 0.123	 accuracy: 64.991 %
# 	 iteration: 21344	 loss: 0.149	 accuracy: 64.299 %
# 	 iteration: 21576	 loss: 0.075	 accuracy: 64.823 %
# epoch:  31
# 	 iteration: 21808	 loss: 0.131	 accuracy: 64.991 %
# 	 iteration: 22040	 loss: 0.137	 accuracy: 64.341 %
# 	 iteration: 22272	 loss: 0.108	 accuracy: 64.823 %
# epoch:  32
# 	 iteration: 22504	 loss: 0.112	 accuracy: 65.095 %
# 	 iteration: 22736	 loss: 0.113	 accuracy: 64.488 %
# 	 iteration: 22968	 loss: 0.058	 accuracy: 64.634 %
# epoch:  33
# 	 iteration: 23200	 loss: 0.053	 accuracy: 65.137 %
# 	 iteration: 23432	 loss: 0.064	 accuracy: 65.766 %
# 	 iteration: 23664	 loss: 0.306	 accuracy: 64.865 %
# epoch:  34
# 	 iteration: 23896	 loss: 0.109	 accuracy: 64.718 %
# 	 iteration: 24128	 loss: 0.033	 accuracy: 65.493 %
# 	 iteration: 24360	 loss: 0.105	 accuracy: 64.111 %
# epoch:  35
# 	 iteration: 24592	 loss: 0.101	 accuracy: 64.844 %
# 	 iteration: 24824	 loss: 0.069	 accuracy: 63.796 %
# 	 iteration: 25056	 loss: 0.120	 accuracy: 64.886 %
# epoch:  36
# 	 iteration: 25288	 loss: 0.071	 accuracy: 64.844 %
# 	 iteration: 25520	 loss: 0.087	 accuracy: 65.095 %
# 	 iteration: 25752	 loss: 0.103	 accuracy: 65.116 %
# epoch:  37
# 	 iteration: 25984	 loss: 0.077	 accuracy: 64.488 %
# 	 iteration: 26216	 loss: 0.031	 accuracy: 64.341 %
# 	 iteration: 26448	 loss: 0.057	 accuracy: 64.488 %
# epoch:  38
# 	 iteration: 26680	 loss: 0.028	 accuracy: 65.032 %
# 	 iteration: 26912	 loss: 0.035	 accuracy: 65.242 %
# 	 iteration: 27144	 loss: 0.038	 accuracy: 64.697 %
# epoch:  39
# 	 iteration: 27376	 loss: 0.054	 accuracy: 65.053 %
# 	 iteration: 27608	 loss: 0.053	 accuracy: 65.095 %
# 	 iteration: 27840	 loss: 0.024	 accuracy: 64.886 %
# epoch:  40
# 	 iteration: 28072	 loss: 0.056	 accuracy: 65.389 %
# 	 iteration: 28304	 loss: 0.009	 accuracy: 65.996 %
# 	 iteration: 28536	 loss: 0.019	 accuracy: 65.535 %
# epoch:  41
# 	 iteration: 28768	 loss: 0.062	 accuracy: 64.781 %
# 	 iteration: 29000	 loss: 0.006	 accuracy: 65.326 %
# 	 iteration: 29232	 loss: 0.017	 accuracy: 64.425 %
# epoch:  42
# 	 iteration: 29464	 loss: 0.008	 accuracy: 66.394 %
# 	 iteration: 29696	 loss: 0.097	 accuracy: 65.535 %
# 	 iteration: 29928	 loss: 0.011	 accuracy: 65.514 %
# epoch:  43
# 	 iteration: 30160	 loss: 0.006	 accuracy: 65.724 %
# 	 iteration: 30392	 loss: 0.043	 accuracy: 65.389 %
# 	 iteration: 30624	 loss: 0.009	 accuracy: 66.227 %
# epoch:  44
# 	 iteration: 30856	 loss: 0.008	 accuracy: 65.368 %
# 	 iteration: 31088	 loss: 0.015	 accuracy: 65.263 %
# 	 iteration: 31320	 loss: 0.010	 accuracy: 65.451 %
# epoch:  45
# 	 iteration: 31552	 loss: 0.009	 accuracy: 65.284 %
# 	 iteration: 31784	 loss: 0.030	 accuracy: 66.143 %
# 	 iteration: 32016	 loss: 0.003	 accuracy: 65.933 %
# epoch:  46
# 	 iteration: 32248	 loss: 0.002	 accuracy: 66.436 %
# 	 iteration: 32480	 loss: 0.002	 accuracy: 66.478 %
# 	 iteration: 32712	 loss: 0.002	 accuracy: 66.122 %
# epoch:  47
# 	 iteration: 32944	 loss: 0.002	 accuracy: 66.310 %
# 	 iteration: 33176	 loss: 0.003	 accuracy: 66.227 %
# 	 iteration: 33408	 loss: 0.001	 accuracy: 65.850 %
# epoch:  48
# 	 iteration: 33640	 loss: 0.002	 accuracy: 66.185 %
# 	 iteration: 33872	 loss: 0.003	 accuracy: 66.520 %
# 	 iteration: 34104	 loss: 0.001	 accuracy: 66.017 %
# epoch:  49
# 	 iteration: 34336	 loss: 0.001	 accuracy: 66.248 %
# 	 iteration: 34568	 loss: 0.002	 accuracy: 66.415 %
# 	 iteration: 34800	 loss: 0.001	 accuracy: 66.227 %
# epoch:  50
# 	 iteration: 35032	 loss: 0.016	 accuracy: 66.185 %
# 	 iteration: 35264	 loss: 0.001	 accuracy: 66.457 %
# 	 iteration: 35496	 loss: 0.002	 accuracy: 66.227 %
# epoch:  51
# 	 iteration: 35728	 loss: 0.005	 accuracy: 66.038 %
# 	 iteration: 35960	 loss: 0.008	 accuracy: 66.227 %
# 	 iteration: 36192	 loss: 0.001	 accuracy: 66.478 %
# epoch:  52
# 	 iteration: 36424	 loss: 0.000	 accuracy: 66.394 %
# 	 iteration: 36656	 loss: 0.001	 accuracy: 66.269 %
# 	 iteration: 36888	 loss: 0.001	 accuracy: 66.122 %
# epoch:  53
# 	 iteration: 37120	 loss: 0.001	 accuracy: 66.248 %
# 	 iteration: 37352	 loss: 0.001	 accuracy: 66.415 %
# 	 iteration: 37584	 loss: 0.001	 accuracy: 66.541 %
# epoch:  54
# 	 iteration: 37816	 loss: 0.001	 accuracy: 66.206 %
# 	 iteration: 38048	 loss: 0.001	 accuracy: 66.478 %
# 	 iteration: 38280	 loss: 0.001	 accuracy: 66.269 %
# epoch:  55
# 	 iteration: 38512	 loss: 0.002	 accuracy: 66.457 %
# 	 iteration: 38744	 loss: 0.000	 accuracy: 66.457 %
# 	 iteration: 38976	 loss: 0.001	 accuracy: 66.373 %
# epoch:  56
# 	 iteration: 39208	 loss: 0.000	 accuracy: 66.248 %
# 	 iteration: 39440	 loss: 0.001	 accuracy: 65.891 %
# 	 iteration: 39672	 loss: 0.001	 accuracy: 66.290 %
# epoch:  57
# 	 iteration: 39904	 loss: 0.001	 accuracy: 66.394 %
# 	 iteration: 40136	 loss: 0.001	 accuracy: 65.766 %
# 	 iteration: 40368	 loss: 0.002	 accuracy: 65.724 %
# epoch:  58
# 	 iteration: 40600	 loss: 0.000	 accuracy: 66.269 %
# 	 iteration: 40832	 loss: 0.000	 accuracy: 66.185 %
# 	 iteration: 41064	 loss: 0.001	 accuracy: 66.227 %
# epoch:  59
# 	 iteration: 41296	 loss: 0.001	 accuracy: 65.891 %
# 	 iteration: 41528	 loss: 0.001	 accuracy: 66.310 %
# 	 iteration: 41760	 loss: 0.002	 accuracy: 66.059 %
# epoch:  60
# 	 iteration: 41992	 loss: 0.001	 accuracy: 66.394 %
# 	 iteration: 42224	 loss: 0.000	 accuracy: 66.248 %
# 	 iteration: 42456	 loss: 0.001	 accuracy: 66.394 %
# epoch:  61
# 	 iteration: 42688	 loss: 0.000	 accuracy: 66.164 %
# 	 iteration: 42920	 loss: 0.001	 accuracy: 66.059 %
# 	 iteration: 43152	 loss: 0.001	 accuracy: 66.478 %
# epoch:  62
# 	 iteration: 43384	 loss: 0.001	 accuracy: 66.248 %
# 	 iteration: 43616	 loss: 0.000	 accuracy: 66.269 %
# 	 iteration: 43848	 loss: 0.001	 accuracy: 66.038 %
# epoch:  63
# 	 iteration: 44080	 loss: 0.000	 accuracy: 66.562 %
# 	 iteration: 44312	 loss: 0.000	 accuracy: 66.227 %
# 	 iteration: 44544	 loss: 0.001	 accuracy: 66.499 %
# epoch:  64
# 	 iteration: 44776	 loss: 0.000	 accuracy: 66.269 %
# 	 iteration: 45008	 loss: 0.000	 accuracy: 66.478 %
# 	 iteration: 45240	 loss: 0.000	 accuracy: 66.352 %
# epoch:  65
# 	 iteration: 45472	 loss: 0.001	 accuracy: 66.646 %
# 	 iteration: 45704	 loss: 0.001	 accuracy: 66.394 %
# 	 iteration: 45936	 loss: 0.000	 accuracy: 66.583 %
# epoch:  66
# 	 iteration: 46168	 loss: 0.000	 accuracy: 66.310 %
# 	 iteration: 46400	 loss: 0.000	 accuracy: 66.457 %
# 	 iteration: 46632	 loss: 0.000	 accuracy: 66.373 %
# epoch:  67
# 	 iteration: 46864	 loss: 0.000	 accuracy: 66.457 %
# 	 iteration: 47096	 loss: 0.000	 accuracy: 66.394 %
# 	 iteration: 47328	 loss: 0.000	 accuracy: 66.541 %
# epoch:  68
# 	 iteration: 47560	 loss: 0.000	 accuracy: 66.478 %
# 	 iteration: 47792	 loss: 0.001	 accuracy: 66.436 %
# 	 iteration: 48024	 loss: 0.000	 accuracy: 66.499 %
# epoch:  69
# 	 iteration: 48256	 loss: 0.000	 accuracy: 66.583 %
# 	 iteration: 48488	 loss: 0.000	 accuracy: 66.604 %
# 	 iteration: 48720	 loss: 0.001	 accuracy: 66.310 %
# epoch:  70
# 	 iteration: 48952	 loss: 0.000	 accuracy: 66.583 %
# 	 iteration: 49184	 loss: 0.000	 accuracy: 66.394 %
# 	 iteration: 49416	 loss: 0.000	 accuracy: 66.457 %
# epoch:  71
# 	 iteration: 49648	 loss: 0.000	 accuracy: 66.436 %
# 	 iteration: 49880	 loss: 0.000	 accuracy: 66.436 %
# 	 iteration: 50112	 loss: 0.000	 accuracy: 66.499 %
# epoch:  72
# 	 iteration: 50344	 loss: 0.000	 accuracy: 66.394 %
# 	 iteration: 50576	 loss: 0.000	 accuracy: 66.562 %
# 	 iteration: 50808	 loss: 0.000	 accuracy: 66.457 %
# epoch:  73
# 	 iteration: 51040	 loss: 0.000	 accuracy: 66.373 %
# 	 iteration: 51272	 loss: 0.000	 accuracy: 66.436 %
# 	 iteration: 51504	 loss: 0.000	 accuracy: 66.436 %
# epoch:  74
# 	 iteration: 51736	 loss: 0.000	 accuracy: 66.436 %
# 	 iteration: 51968	 loss: 0.000	 accuracy: 66.541 %
# 	 iteration: 52200	 loss: 0.000	 accuracy: 66.499 %
# epoch:  75
# 	 iteration: 52432	 loss: 0.000	 accuracy: 66.625 %
# 	 iteration: 52664	 loss: 0.001	 accuracy: 66.646 %
# 	 iteration: 52896	 loss: 0.001	 accuracy: 66.436 %
# epoch:  76
# 	 iteration: 53128	 loss: 0.000	 accuracy: 66.499 %
# 	 iteration: 53360	 loss: 0.000	 accuracy: 66.499 %
# 	 iteration: 53592	 loss: 0.000	 accuracy: 66.541 %
# epoch:  77
# 	 iteration: 53824	 loss: 0.001	 accuracy: 66.520 %
# 	 iteration: 54056	 loss: 0.000	 accuracy: 66.394 %
# 	 iteration: 54288	 loss: 0.001	 accuracy: 66.541 %
# epoch:  78
# 	 iteration: 54520	 loss: 0.000	 accuracy: 66.415 %
# 	 iteration: 54752	 loss: 0.000	 accuracy: 66.499 %
# 	 iteration: 54984	 loss: 0.001	 accuracy: 66.541 %
# epoch:  79
# 	 iteration: 55216	 loss: 0.000	 accuracy: 66.562 %
# 	 iteration: 55448	 loss: 0.000	 accuracy: 66.394 %
# 	 iteration: 55680	 loss: 0.000	 accuracy: 66.541 %
# epoch:  80
# 	 iteration: 55912	 loss: 0.000	 accuracy: 66.541 %
# 	 iteration: 56144	 loss: 0.000	 accuracy: 66.436 %
# 	 iteration: 56376	 loss: 0.000	 accuracy: 66.604 %
# epoch:  81
# 	 iteration: 56608	 loss: 0.001	 accuracy: 66.394 %
# 	 iteration: 56840	 loss: 0.000	 accuracy: 66.478 %
# 	 iteration: 57072	 loss: 0.000	 accuracy: 66.436 %
# epoch:  82
# 	 iteration: 57304	 loss: 0.000	 accuracy: 66.520 %
# 	 iteration: 57536	 loss: 0.000	 accuracy: 66.499 %
# 	 iteration: 57768	 loss: 0.001	 accuracy: 66.541 %
# epoch:  83
# 	 iteration: 58000	 loss: 0.000	 accuracy: 66.583 %
# 	 iteration: 58232	 loss: 0.000	 accuracy: 66.436 %
# 	 iteration: 58464	 loss: 0.000	 accuracy: 66.541 %
# epoch:  84
# 	 iteration: 58696	 loss: 0.000	 accuracy: 66.499 %
# 	 iteration: 58928	 loss: 0.000	 accuracy: 66.625 %
# 	 iteration: 59160	 loss: 0.000	 accuracy: 66.478 %
# epoch:  85
# 	 iteration: 59392	 loss: 0.000	 accuracy: 66.457 %
# 	 iteration: 59624	 loss: 0.000	 accuracy: 66.520 %
# 	 iteration: 59856	 loss: 0.000	 accuracy: 66.499 %
# epoch:  86
# 	 iteration: 60088	 loss: 0.000	 accuracy: 66.373 %
# 	 iteration: 60320	 loss: 0.000	 accuracy: 66.562 %
# 	 iteration: 60552	 loss: 0.000	 accuracy: 66.541 %
# epoch:  87
# 	 iteration: 60784	 loss: 0.000	 accuracy: 66.499 %
# 	 iteration: 61016	 loss: 0.000	 accuracy: 66.541 %
# 	 iteration: 61248	 loss: 0.000	 accuracy: 66.415 %
# epoch:  88
# 	 iteration: 61480	 loss: 0.000	 accuracy: 66.541 %
# 	 iteration: 61712	 loss: 0.000	 accuracy: 66.478 %
# 	 iteration: 61944	 loss: 0.001	 accuracy: 66.499 %
# epoch:  89
# 	 iteration: 62176	 loss: 0.000	 accuracy: 66.520 %
# 	 iteration: 62408	 loss: 0.000	 accuracy: 66.520 %
# 	 iteration: 62640	 loss: 0.000	 accuracy: 66.499 %
# epoch:  90
# 	 iteration: 62872	 loss: 0.000	 accuracy: 66.436 %
# 	 iteration: 63104	 loss: 0.000	 accuracy: 66.415 %
# 	 iteration: 63336	 loss: 0.000	 accuracy: 66.352 %
# epoch:  91
# 	 iteration: 63568	 loss: 0.000	 accuracy: 66.478 %
# 	 iteration: 63800	 loss: 0.000	 accuracy: 66.499 %
# 	 iteration: 64032	 loss: 0.000	 accuracy: 66.520 %
# epoch:  92
# 	 iteration: 64264	 loss: 0.000	 accuracy: 66.520 %
# 	 iteration: 64496	 loss: 0.000	 accuracy: 66.667 %
# 	 iteration: 64728	 loss: 0.000	 accuracy: 66.562 %
# epoch:  93
# 	 iteration: 64960	 loss: 0.000	 accuracy: 66.541 %
# 	 iteration: 65192	 loss: 0.000	 accuracy: 66.541 %
# 	 iteration: 65424	 loss: 0.000	 accuracy: 66.562 %
# epoch:  94
# 	 iteration: 65656	 loss: 0.000	 accuracy: 66.583 %
# 	 iteration: 65888	 loss: 0.000	 accuracy: 66.562 %
# 	 iteration: 66120	 loss: 0.000	 accuracy: 66.604 %
# epoch:  95
# 	 iteration: 66352	 loss: 0.000	 accuracy: 66.667 %
# 	 iteration: 66584	 loss: 0.000	 accuracy: 66.436 %
# 	 iteration: 66816	 loss: 0.000	 accuracy: 66.583 %
# epoch:  96
# 	 iteration: 67048	 loss: 0.000	 accuracy: 66.520 %
# 	 iteration: 67280	 loss: 0.000	 accuracy: 66.520 %
# 	 iteration: 67512	 loss: 0.000	 accuracy: 66.415 %
# epoch:  97
# 	 iteration: 67744	 loss: 0.000	 accuracy: 66.625 %
# 	 iteration: 67976	 loss: 0.000	 accuracy: 66.562 %
# 	 iteration: 68208	 loss: 0.000	 accuracy: 66.499 %
# epoch:  98
# 	 iteration: 68440	 loss: 0.000	 accuracy: 66.478 %
# 	 iteration: 68672	 loss: 0.001	 accuracy: 66.562 %
# 	 iteration: 68904	 loss: 0.000	 accuracy: 66.562 %
# epoch:  99
# 	 iteration: 69136	 loss: 0.000	 accuracy: 66.457 %
# 	 iteration: 69368	 loss: 0.000	 accuracy: 66.499 %
# 	 iteration: 69600	 loss: 0.000	 accuracy: 66.625 %
# time elapsed:  8671.56  sec
